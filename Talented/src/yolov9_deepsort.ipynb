# %% [markdown]
# # **Install all the Dependencies**

# %%
from IPython.display import HTML
from base64 import b64encode
def play_video(filename):
  html = ''
  video = open(filename,'rb').read()
  src = 'data:video/mp4;base64,' + b64encode(video).decode()
  html += fr'' % src
  return HTML(html)

# %%
from IPython.display import YouTubeVideo

YOUTUBE_ID = 'Utky2IXgOQI'
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Utky2IXgOQI
# [youtube] Utky2IXgOQI: Downloading webpage
# [youtube] Utky2IXgOQI: Downloading tv client config
# [youtube] Utky2IXgOQI: Downloading player 9a279502-main
# [youtube] Utky2IXgOQI: Downloading tv player API JSON
# [youtube] Utky2IXgOQI: Downloading ios player API JSON
# [youtube] Utky2IXgOQI: Downloading m3u8 information
# ERROR: [youtube] Utky2IXgOQI: Requested format is not available. Use --list-formats for a list of available formats

# %% [markdown]
# ## Importing Core Libraries

# %%
import cv2
import torch
import time
import numpy as np
from absl.flags import FLAGS
from deep_sort_realtime.deepsort_tracker import DeepSort
from ultralytics import YOLO
import mediapipe as mp

# %% [markdown]
# ## Draw Corner-Style Bounding Box

# %%
def draw_corner_rect(img, bbox, line_length=30, line_thickness=5, rect_thickness=1,
                     rect_color=(255, 0, 255), line_color=(0, 255, 0)):
    x, y, w, h = bbox
    x1, y1 = x + w, y + h

    if rect_thickness != 0:
        cv2.rectangle(img, bbox, rect_color, rect_thickness)

    # Top Left  x, y
    cv2.line(img, (x, y), (x + line_length, y), line_color, line_thickness)
    cv2.line(img, (x, y), (x, y + line_length), line_color, line_thickness)

    # Top Right  x1, y
    cv2.line(img, (x1, y), (x1 - line_length, y), line_color, line_thickness)
    cv2.line(img, (x1, y), (x1, y + line_length), line_color, line_thickness)

    # Bottom Left  x, y1
    cv2.line(img, (x, y1), (x + line_length, y1), line_color, line_thickness)
    cv2.line(img, (x, y1), (x, y1 - line_length), line_color, line_thickness)

    # Bottom Right  x1, y1
    cv2.line(img, (x1, y1), (x1 - line_length, y1), line_color, line_thickness)
    cv2.line(img, (x1, y1), (x1, y1 - line_length), line_color, line_thickness)

    return img

# %%
SOURCE_VIDEO_PATH = "../data/youtube.mp4"
OUTPUT_VIDEO_PATH = "../data/output.mp4"
BLUR_ID = None
CONF = 0.8
CLASS_ID = None
OUTPUT_CSV_PATH = "../data/player_metrics.csv"

# %%
model = YOLO("models/yolov9s.pt")

# %% [markdown]
# ## Initializing VideoCapture & VideoWriter with DeepSort Tracking and Device Selection

# %%
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
# video writer objects
fourcc = cv2.VideoWriter_fourcc(*'XVID')
writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))

if not writer.isOpened():
    print("Failed to open VideoWriter!")
    cap.release()
    exit(1)

# Initialize the DeepSort tracker
tracker = DeepSort(max_age=50)
# select device (CPU or GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## YOLOv9 + DeepSort

# %% [markdown]
# # Generate random colors for each class
# np.random.seed(42)
# colors = np.random.randint(0, 255, size=(len(model.names), 3))
#
# # Parameters
# CONF    = 0.8            # confidence threshold
# ALLOWED = [0, 32]        # 0=person, 32=sports ball
#
# # Manual ball tracking
# ball_id         = 1
# last_ball_bbox  = None   # will hold [x, y, w, h] of the ball
#
# # FPS calculation
# frame_count = 0
# start_time  = time.time()
#
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # 1. Run detection
#     results = model(frame)
#     r       = results[0]
#     xyxy    = r.boxes.xyxy.cpu().numpy()
#     confs   = r.boxes.conf.cpu().numpy()
#     cls_ids = r.boxes.cls.cpu().numpy().astype(int)
#
#     # 2. Build filtered detection list
#     detect = []
#     for (x1, y1, x2, y2), conf, cid in zip(xyxy, confs, cls_ids):
#         if conf < CONF or cid not in ALLOWED:
#             continue
#         detect.append([[int(x1), int(y1), int(x2 - x1), int(y2 - y1)],
#                        float(conf), int(cid)])
#
#     # 3. Track persons with DeepSort
#     person_detections = [d for d in detect if d[2] == 0]
#     tracks            = tracker.update_tracks(person_detections, frame=frame)
#
#     # 4. Manual track for the single sports ball
#     ball_candidates = [d for d in detect if d[2] == 32]
#     if ball_candidates:
#         best_ball       = max(ball_candidates, key=lambda x: x[1])
#         last_ball_bbox  = best_ball[0]
#
#     # 5. Draw person tracking results
#     for track in tracks:
#         if not track.is_confirmed():
#             continue
#
#         tid       = track.track_id
#         x1, y1, x2, y2 = map(int, track.to_ltrb())
#         cid       = track.get_det_class()  # should be 0
#         color     = colors[cid]
#         B, G, R   = map(int, color)
#         label     = f"{tid} - {model.names[cid]}"
#
#         # draw corner-style box
#         frame = draw_corner_rect(
#             frame,
#             (x1, y1, x2 - x1, y2 - y1),
#             line_length=15,
#             line_thickness=3,
#             rect_thickness=1,
#             rect_color=(B, G, R),
#             line_color=(R, G, B),
#         )
#         # draw solid rectangle and label background
#         cv2.rectangle(frame, (x1, y1), (x2, y2), (B, G, R), 2)
#         cv2.rectangle(
#             frame,
#             (x1 - 1, y1 - 20),
#             (x1 + len(label) * 10, y1),
#             (B, G, R),
#             -1
#         )
#         cv2.putText(
#             frame,
#             label,
#             (x1 + 5, y1 - 7),
#             cv2.FONT_HERSHEY_SIMPLEX,
#             0.5,
#             (255, 255, 255),
#             2
#         )
#
#     # 6. Draw the sports ball with fixed ID
#     if last_ball_bbox is not None:
#         x, y, w, h = last_ball_bbox
#         color       = colors[32]
#         B, G, R     = map(int, color)
#         label       = f"{ball_id} - sports ball"
#
#         frame = draw_corner_rect(
#             frame,
#             (x, y, w, h),
#             line_length=15,
#             line_thickness=3,
#             rect_thickness=1,
#             rect_color=(B, G, R),
#             line_color=(R, G, B),
#         )
#         cv2.rectangle(frame, (x, y), (x + w, y + h), (B, G, R), 2)
#         cv2.rectangle(frame, (x - 1, y - 20), (x + len(label) * 10, y), (B, G, R), -1)
#         cv2.putText(frame, label, (x + 5, y - 7),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#
#     # 7. Write frame and update FPS
#     writer.write(frame)
#     frame_count += 1
#     if frame_count % 10 == 0:
#         fps_calc = frame_count / (time.time() - start_time)
#         print(f"FPS: {fps_calc:.2f}")
#
#     # Exit on 'q'
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# # Release resources after loop
# cap.release()
# writer.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ## YOLOv9 + DeepSort + MediaPipe

# %%
import numpy as np

def assess_speed_quality(speeds_pps, px_to_m):
    """
    Evaluates player speed quality based on average speed in m/s.

    Args:
        speeds_pps: list of floats, speeds in pixels per second.
        px_to_m: float, conversion factor from pixel to meter (m/px).

    Returns:
        dict with:
            - 'average_speed_mps': average speed in meters/second
            - 'max_speed_mps': maximum speed in meters/second
            - 'quality': one of 'Excellent Speed', 'Good Speed', 'Poor Speed'
            - 'description': English description of the quality
    """
    # Convert to m/s
    valid_pps = [s for s in speeds_pps if s is not None and s > 0]
    speeds_mps = [s * px_to_m for s in valid_pps] if valid_pps else [0.0]
    
    average_speed_mps = float(np.mean(speeds_mps))
    max_speed_mps = float(np.max(speeds_mps))
    
    # Classify quality based on average speed
    if average_speed_mps >= 6.0:
        quality = 'Excellent Speed'
        description = (
            'Player demonstrates very high average speed (>=6 m/s), '
            'able to outrun opponents and cover ground effectively.'
        )
    elif average_speed_mps >= 4.0:
        quality = 'Good Speed'
        description = (
            'Player maintains solid speed (4–6 m/s) in most game situations, '
            'supporting both offensive runs and defensive recoveries.'
        )
    else:
        quality = 'Poor Speed'
        description = (
            "Player's average speed (<4 m/s) is below desired levels, "
            'which may limit ability to keep up with play pace.'
        )
    
    return {
        'average_speed_mps': average_speed_mps,
        'max_speed_mps': max_speed_mps,
        'quality': quality,
        'description': description
    }

# Example usage:
# px_to_m = 0.02
# result = assess_speed_quality(speed_history[player_id], px_to_m)
# print(result)

# %%
import math
import numpy as np

def assess_ball_control_quality(keypoints_history, ball_history, px_to_m, foot_indices=(27, 28)):
    """
    Calculates average distance between the ball and player's feet (in meters), then categorizes control quality.

    Returns:
        dict with:
        - 'avg_distance_m': average distance in meters
        - 'quality': one of 'Excellent Control', 'Good Control', 'Poor Control'
        - 'description': English description of the control quality
    """
    distances_m = []
    n = min(len(keypoints_history), len(ball_history))
    
    for i in range(n):
        kps = keypoints_history[i]
        ball = ball_history[i]
        if ball is None or not kps:
            continue
        
        # Calculate minimum distance in pixels between ball and any foot
        pts = [kps[idx] for idx in foot_indices if idx < len(kps)]
        dists_px = [math.hypot(ball[0] - px, ball[1] - py) for px, py in pts]
        if not dists_px:
            continue
        
        # Convert to meters
        min_dist_m = min(dists_px) * px_to_m
        distances_m.append(min_dist_m)
    
    if not distances_m:
        return {
            'avg_distance_m': None,
            'quality': 'Poor Control',
            'description': 'Insufficient data to assess control quality.'
        }
    
    avg_dist = float(np.mean(distances_m))
    
    # Determine control quality
    if avg_dist < 1.0:
        quality = 'Excellent Control'
        description = (
            'Ball remains very close to the player’s feet (under 1 meter), '
            'allowing quick decision-making for passing, shooting, or dribbling.'
        )
    elif avg_dist < 2.0:
        quality = 'Good Control'
        description = (
            'Ball is slightly farther (1–2 meters), but the player still '
            'manages it comfortably without heavy opponent pressure.'
        )
    else:
        quality = 'Poor Control'
        description = (
            'Ball drifts beyond 2 meters, increasing the risk of losing '
            'possession or reducing attacking effectiveness.'
        )
    
    return {
        'avg_distance_m': avg_dist,
        'quality': quality,
        'description': description
    }

# %%
import math
import numpy as np

def assess_self_passes(keypoints_history, ball_history, px_to_m,
                       foot_indices=(27, 28),
                       control_thresh_m=0.5):
    """
    Detects self-pass events where the player kicks the ball and then regains control.
    Classifies each event based on the distance traveled by the ball before returning.

    Args:
        keypoints_history: list of lists of (x,y) pixel coords per frame
        ball_history: list of (x,y) pixel coords or None per frame
        px_to_m: conversion factor from pixel to meter (m/px)
        foot_indices: indices for foot landmarks in MediaPipe
        control_thresh_m: distance in meters defining control proximity

    Returns:
        List of dicts, each with:
            - 'distance_m': float, max distance ball traveled before return
            - 'quality': str category ('Excellent Self Pass', 'Effective Self Pass', 'Poor Self Pass')
            - 'description': English description of quality
            - 'start_frame': frame index where pass started
            - 'end_frame': frame index where pass ended
    """
    control_thresh_px = control_thresh_m / px_to_m
    events = []
    in_pass = False
    start_frame = None
    max_dist_px = 0
    
    n = min(len(keypoints_history), len(ball_history))
    
    for i in range(n):
        kps = keypoints_history[i]
        ball = ball_history[i]
        if ball is None or not kps:
            # Reset if lost tracking
            if in_pass:
                in_pass = False
                start_frame = None
                max_dist_px = 0
            continue
        
        # Compute foot centroid
        feet = [kps[idx] for idx in foot_indices if idx < len(kps)]
        if not feet:
            continue
        fx = sum(p[0] for p in feet) / len(feet)
        fy = sum(p[1] for p in feet) / len(feet)
        
        dist_px = math.hypot(ball[0] - fx, ball[1] - fy)
        
        if not in_pass:
            # Begin pass when ball leaves control area
            if dist_px > control_thresh_px:
                in_pass = True
                start_frame = i
                max_dist_px = dist_px
        else:
            # Update max distance
            if dist_px > max_dist_px:
                max_dist_px = dist_px
            # End pass when ball returns to control area
            if dist_px <= control_thresh_px:
                end_frame = i
                # Convert max distance to meters
                distance_m = max_dist_px * px_to_m
                # Classify
                if 2 <= distance_m < 5:
                    quality = 'Excellent Self Pass'
                    description = (
                        'Player pushes the ball 2–5 meters ahead into space, '
                        'bypassing opponents and regaining it without defensive intervention. '
                        'Ideal for dribbling or speeding up play.'
                    )
                elif 5 <= distance_m < 8:
                    quality = 'Effective Self Pass'
                    description = (
                        'Ball travels 5–8 meters, requiring speed and response to chase. '
                        'Used for long passes to bypass defenders or quick wing play; '
                        'successful if no defender intercepts.'
                    )
                else:
                    quality = 'Poor Self Pass'
                    description = (
                        'Ball is sent over 8 meters, increasing interception risk '
                        'or loss of control. Often deemed a misplaced or overly strong pass.'
                    )
                events.append({
                    'distance_m': distance_m,
                    'quality': quality,
                    'description': description,
                    'start_frame': start_frame,
                    'end_frame': end_frame
                })
                # Reset for next pass
                in_pass = False
                start_frame = None
                max_dist_px = 0
    
    return events

# Example usage:
# px_to_m = 0.02  # conversion factor
# events = assess_self_passes(keypoints_history[player_id], ball_history, px_to_m)
# print(events)

# %%
import pandas as pd

def export_player_metrics_to_csv(speed_history, keypoints_history, ball_history, px_to_m, output_path):
    """
    Aggregates player performance metrics and writes them to a CSV file.

    Args:
        speed_history (dict): {player_id: [speeds_pps]}
        keypoints_history (dict): {player_id: [[(x,y), ...], ...]}
        ball_history (list): [(x,y) or None] per frame
        px_to_m (float): conversion factor from pixel to meter
        output_path (str): file path for the CSV output

    Returns:
        None
    """
    rows = []
    for player_id, speeds in speed_history.items():
        # Speed assessment
        speed_res = assess_speed_quality(speeds, px_to_m)
        
        # Ball control assessment
        control_res = assess_ball_control_quality(
            keypoints_history.get(player_id, []),
            ball_history,
            px_to_m
        )
        
        # Self-pass events and counts
        self_pass_events = assess_self_passes(
            keypoints_history.get(player_id, []),
            ball_history,
            px_to_m
        )
        count_excellent = sum(1 for e in self_pass_events if e['quality'] == 'Excellent Self Pass')
        count_effective = sum(1 for e in self_pass_events if e['quality'] == 'Effective Self Pass')
        count_poor = sum(1 for e in self_pass_events if e['quality'] == 'Poor Self Pass')
        
        rows.append({
            'player_id': player_id,
            'avg_speed_mps': speed_res['average_speed_mps'],
            'max_speed_mps': speed_res['max_speed_mps'],
            'speed_quality': speed_res['quality'],
            'avg_control_distance_m': control_res['avg_distance_m'],
            'control_quality': control_res['quality'],
            'num_excellent_self_pass': count_excellent,
            'num_effective_self_pass': count_effective,
            'num_poor_self_pass': count_poor
        })

    df = pd.DataFrame(rows)
    df.to_csv(output_path, index=False)
    print(f"Player metrics exported to {output_path}")

# Example usage:
# export_player_metrics_to_csv(speed_history, keypoints_history, ball_history, px_to_m, 'player_metrics.csv')

# %%
# MediaPipe Pose
mp_drawing = mp.solutions.drawing_utils
mp_pose    = mp.solutions.pose
pose       = mp_pose.Pose(
    static_image_mode=False,
    model_complexity=1,
    enable_segmentation=False,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

# YOLO & DeepSort setup assumed done: model, tracker, cap, writer...
# Generate random colors for each class
np.random.seed(42)
colors = np.random.randint(0, 255, size=(len(model.names), 3))

# Parameters
CONF    = 0.8            # confidence threshold
ALLOWED = [0, 32]        # 0=person, 32=sports ball

# Manual ball tracking
ball_id         = 1
last_ball_bbox  = None   # will hold [x, y, w, h] of the ball

# FPS calculation
frame_count = 0
start_time  = time.time()

# Initialize evaluation histories
speed_history = {}
keypoints_history = {}
ball_history = []
prev_positions = {}

# Main loop
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # 1. Detection
    results = model(frame)[0]
    xyxy = results.boxes.xyxy.cpu().numpy()
    confs = results.boxes.conf.cpu().numpy()
    cls_ids = results.boxes.cls.cpu().numpy().astype(int)

    detect = [
        [[int(x1), int(y1), int(x2 - x1), int(y2 - y1)], float(conf), int(cid)]
        for (x1, y1, x2, y2), conf, cid in zip(xyxy, confs, cls_ids)
        if conf >= CONF and cid in ALLOWED
    ]

    # 2. Person tracking
    person_dets = detect = [d for d in detect if d[2] == 0]
    tracks = tracker.update_tracks(person_dets, frame=frame)

    # 3. Ball tracking
    ball_candidates = [d for d in detect if d[2] == 32]
    ball_center = None
    if ball_candidates:
        bx, by, bw, bh = max(ball_candidates, key=lambda x: x[1])[0]
        ball_center = (bx + bw/2, by + bh/2)
    ball_history.append(ball_center)

    # 4. Pose + metrics per person
    for track in tracks:
        if not track.is_confirmed():
            continue
        tid = track.track_id
        x1, y1, x2, y2 = map(int, track.to_ltrb())
        person_roi = frame[y1:y2, x1:x2]
        if person_roi.size == 0:
            continue

        # Pose estimation
        roi_rgb = cv2.cvtColor(person_roi, cv2.COLOR_BGR2RGB)
        res = pose.process(roi_rgb)
        if not res.pose_landmarks:
            continue

        # Convert landmarks to pixel coords
        h_roi, w_roi = person_roi.shape[:2]
        kps = []
        for lm in res.pose_landmarks.landmark:
            px = int(lm.x * w_roi) + x1
            py = int(lm.y * h_roi) + y1
            kps.append((px, py))
        keypoints_history.setdefault(tid, []).append(kps)


        # Calculate speed using hip landmark (24) via prev_positions
        now = time.time()
        hip_x, hip_y = kps[24]  # مفصل الحوض

        if tid in prev_positions:
            x_prev, y_prev, t_prev = prev_positions[tid]
            dt = now - t_prev or 1e-6
            speed = math.hypot(hip_x - x_prev, hip_y - y_prev) / dt
            speed_history.setdefault(tid, []).append(speed)
        else:
            speed_history.setdefault(tid, []).append(0.0)

        # حدّث prev_positions بالموضع والوقت الحاليين
        prev_positions[tid] = (hip_x, hip_y, now)


        # Draw landmarks on ROI
        mp_drawing.draw_landmarks(
            person_roi,
            res.pose_landmarks,
            mp_pose.POSE_CONNECTIONS
        )
        frame[y1:y2, x1:x2] = person_roi

    # 5. Draw detections & tracks...
    # [existing draw_corner_rect and ball code here]

    # 5. Draw person tracking results
    for track in tracks:
        if not track.is_confirmed():
            continue

        tid       = track.track_id
        x1, y1, x2, y2 = map(int, track.to_ltrb())
        cid       = track.get_det_class()  # should be 0
        color     = colors[cid]
        B, G, R   = map(int, color)
        label     = f"{tid} - {model.names[cid]}"

        # draw corner-style box
        frame = draw_corner_rect(
            frame,
            (x1, y1, x2 - x1, y2 - y1),
            line_length=15,
            line_thickness=3,
            rect_thickness=1,
            rect_color=(B, G, R),
            line_color=(R, G, B),
        )
        # draw solid rectangle and label background
        cv2.rectangle(frame, (x1, y1), (x2, y2), (B, G, R), 2)
        cv2.rectangle(
            frame,
            (x1 - 1, y1 - 20),
            (x1 + len(label) * 10, y1),
            (B, G, R),
            -1
        )
        cv2.putText(
            frame,
            label,
            (x1 + 5, y1 - 7),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (255, 255, 255),
            2
        )

    # 6. Draw the sports ball with fixed ID
    if last_ball_bbox is not None:
        x, y, w, h = last_ball_bbox
        color       = colors[32]
        B, G, R     = map(int, color)
        label       = f"{ball_id} - sports ball"

        frame = draw_corner_rect(
            frame,
            (x, y, w, h),
            line_length=15,
            line_thickness=3,
            rect_thickness=1,
            rect_color=(B, G, R),
            line_color=(R, G, B),
        )
        cv2.rectangle(frame, (x, y), (x + w, y + h), (B, G, R), 2)
        cv2.rectangle(frame, (x - 1, y - 20), (x + len(label) * 10, y), (B, G, R), -1)
        cv2.putText(frame, label, (x + 5, y - 7),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # 6. Evaluate and export player metrics to csv 
    px_to_m = 0.02  # e.g. 1 pixel = 0.02 meters
    export_player_metrics_to_csv(
            speed_history,
            keypoints_history,
            ball_history,
            px_to_m,
            OUTPUT_CSV_PATH
        )

    # 7. Write and show
    writer.write(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
writer.release()
cv2.destroyAllWindows()
pose.close()
# Out:
# 0: 640x384 1 person, 1 sports ball, 333.3ms
# Speed: 2.2ms preprocess, 333.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 0.0, 'max_speed_pps': 0.0}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 0.0, 'max_speed_pps': 0.0}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 208.1ms
# Speed: 3.4ms preprocess, 208.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 21.672014144565146, 'max_speed_pps': 43.34402828913029}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 21.672014144565146, 'max_speed_pps': 43.34402828913029}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 216.7ms
# Speed: 3.3ms preprocess, 216.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 17.74040398834765, 'max_speed_pps': 43.34402828913029}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 17.74040398834765, 'max_speed_pps': 43.34402828913029}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.1ms
# Speed: 4.3ms preprocess, 222.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 29.24873066942438, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 29.24873066942438, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 241.0ms
# Speed: 3.3ms preprocess, 241.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 28.39503675822465, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 28.39503675822465, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 253.4ms
# Speed: 3.2ms preprocess, 253.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 32.33291460893047, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 32.33291460893047, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 496.1ms
# Speed: 5.8ms preprocess, 496.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 29.359330813835435, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 29.359330813835435, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 381.3ms
# Speed: 3.6ms preprocess, 381.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 30.36544315228732, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 30.36544315228732, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 383.2ms
# Speed: 3.8ms preprocess, 383.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 33.39624187948594, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 33.39624187948594, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 1 kite, 384.8ms
# Speed: 4.4ms preprocess, 384.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 33.770378585747444, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 33.770378585747444, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 1 kite, 369.0ms
# Speed: 6.0ms preprocess, 369.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 34.80732177706165, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 34.80732177706165, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 kite, 297.9ms
# Speed: 3.3ms preprocess, 297.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 36.075599674347785, 'max_speed_pps': 63.773710712654555}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 36.075599674347785, 'max_speed_pps': 63.773710712654555}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 kite, 348.8ms
# Speed: 4.3ms preprocess, 348.8ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 38.454139061897585, 'max_speed_pps': 66.99661171249524}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 38.454139061897585, 'max_speed_pps': 66.99661171249524}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 234.5ms
# Speed: 2.8ms preprocess, 234.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 40.888585018923436, 'max_speed_pps': 72.53638246025952}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 40.888585018923436, 'max_speed_pps': 72.53638246025952}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 214.9ms
# Speed: 2.7ms preprocess, 214.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 43.33818405811847, 'max_speed_pps': 77.63257060684892}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 43.33818405811847, 'max_speed_pps': 77.63257060684892}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.8ms
# Speed: 3.3ms preprocess, 223.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.14485371777139, 'max_speed_pps': 77.63257060684892}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.14485371777139, 'max_speed_pps': 77.63257060684892}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 229.3ms
# Speed: 3.0ms preprocess, 229.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 44.0822958395348, 'max_speed_pps': 77.63257060684892}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 44.0822958395348, 'max_speed_pps': 77.63257060684892}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 217.3ms
# Speed: 3.3ms preprocess, 217.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 44.22183705660937, 'max_speed_pps': 77.63257060684892}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 44.22183705660937, 'max_speed_pps': 77.63257060684892}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 217.7ms
# Speed: 2.8ms preprocess, 217.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.544555859126724, 'max_speed_pps': 77.63257060684892}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.544555859126724, 'max_speed_pps': 77.63257060684892}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 217.4ms
# Speed: 3.0ms preprocess, 217.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 47.65816172866672, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 47.65816172866672, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.5ms
# Speed: 2.8ms preprocess, 223.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.603097631088296, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.603097631088296, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 219.9ms
# Speed: 2.7ms preprocess, 219.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.97637670584687, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.97637670584687, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 215.0ms
# Speed: 3.1ms preprocess, 215.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.309891257921386, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.309891257921386, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 216.4ms
# Speed: 2.7ms preprocess, 216.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.37569118454971, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.37569118454971, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.4ms
# Speed: 3.5ms preprocess, 222.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.743285328796944, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.743285328796944, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 221.6ms
# Speed: 3.1ms preprocess, 221.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.3675741790946, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.3675741790946, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.3ms
# Speed: 3.4ms preprocess, 223.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 45.29944275536741, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 45.29944275536741, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 229.7ms
# Speed: 2.8ms preprocess, 229.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.50268024053623, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.50268024053623, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 224.1ms
# Speed: 3.7ms preprocess, 224.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.01617707033758, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.01617707033758, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 213.2ms
# Speed: 2.8ms preprocess, 213.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.40475144429775, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.40475144429775, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 224.1ms
# Speed: 3.9ms preprocess, 224.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 46.7547253594243, 'max_speed_pps': 87.81667324992661}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 46.7547253594243, 'max_speed_pps': 87.81667324992661}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 224.9ms
# Speed: 3.1ms preprocess, 224.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 49.066460672504064, 'max_speed_pps': 120.73025537797685}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 49.066460672504064, 'max_speed_pps': 120.73025537797685}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 232.6ms
# Speed: 3.3ms preprocess, 232.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 51.285694779899245, 'max_speed_pps': 122.30118621654509}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 51.285694779899245, 'max_speed_pps': 122.30118621654509}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 220.1ms
# Speed: 3.3ms preprocess, 220.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 52.06427172125235, 'max_speed_pps': 122.30118621654509}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 52.06427172125235, 'max_speed_pps': 122.30118621654509}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 224.5ms
# Speed: 3.7ms preprocess, 224.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 53.33808631511033, 'max_speed_pps': 122.30118621654509}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 53.33808631511033, 'max_speed_pps': 122.30118621654509}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 226.9ms
# Speed: 4.1ms preprocess, 226.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 54.32107493899919, 'max_speed_pps': 122.30118621654509}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 54.32107493899919, 'max_speed_pps': 122.30118621654509}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 215.6ms
# Speed: 4.0ms preprocess, 215.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 55.947388410853165, 'max_speed_pps': 122.30118621654509}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 55.947388410853165, 'max_speed_pps': 122.30118621654509}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.0ms
# Speed: 3.7ms preprocess, 222.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.103199555272724, 'max_speed_pps': 137.8682118987967}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.103199555272724, 'max_speed_pps': 137.8682118987967}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 218.1ms
# Speed: 3.5ms preprocess, 218.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.29056452724062, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.29056452724062, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 234.3ms
# Speed: 3.0ms preprocess, 234.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.25282922778605, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.25282922778605, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 221.2ms
# Speed: 3.2ms preprocess, 221.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.89252366423389, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.89252366423389, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.8ms
# Speed: 2.6ms preprocess, 222.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.416496953700374, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.416496953700374, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 228.8ms
# Speed: 3.9ms preprocess, 228.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.49072227424709, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.49072227424709, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 216.6ms
# Speed: 3.2ms preprocess, 216.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.74815097949456, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.74815097949456, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 215.9ms
# Speed: 4.2ms preprocess, 215.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.87504409620772, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.87504409620772, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 218.1ms
# Speed: 3.5ms preprocess, 218.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 64.4910923277281, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 64.4910923277281, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 225.8ms
# Speed: 3.3ms preprocess, 225.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 65.78477398704442, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 65.78477398704442, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 233.6ms
# Speed: 3.2ms preprocess, 233.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 66.05899674708095, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 66.05899674708095, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.3ms
# Speed: 3.8ms preprocess, 223.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 66.32355479082497, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 66.32355479082497, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 231.5ms
# Speed: 3.2ms preprocess, 231.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 65.3371216336682, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 65.3371216336682, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 228.6ms
# Speed: 4.2ms preprocess, 228.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 64.94489162080649, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 64.94489162080649, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 227.3ms
# Speed: 3.0ms preprocess, 227.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 64.14621004072653, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 64.14621004072653, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.4ms
# Speed: 3.3ms preprocess, 222.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.8712296809125, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.8712296809125, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.9ms
# Speed: 3.1ms preprocess, 222.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.71303942966915, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.71303942966915, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 280.5ms
# Speed: 3.8ms preprocess, 280.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.133120000306, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.133120000306, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 247.0ms
# Speed: 4.5ms preprocess, 247.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.3284592336171, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.3284592336171, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 235.7ms
# Speed: 3.6ms preprocess, 235.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.25473100736499, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.25473100736499, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 232.1ms
# Speed: 3.8ms preprocess, 232.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.599664180851065, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.599664180851065, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 229.5ms
# Speed: 3.2ms preprocess, 229.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 229.0ms
# Speed: 3.7ms preprocess, 229.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 240.7ms
# Speed: 5.5ms preprocess, 240.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 276.3ms
# Speed: 3.6ms preprocess, 276.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 219.6ms
# Speed: 2.9ms preprocess, 219.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 230.4ms
# Speed: 3.5ms preprocess, 230.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 241.5ms
# Speed: 3.7ms preprocess, 241.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 248.0ms
# Speed: 3.9ms preprocess, 248.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 285.3ms
# Speed: 3.4ms preprocess, 285.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 232.4ms
# Speed: 3.2ms preprocess, 232.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 231.2ms
# Speed: 2.9ms preprocess, 231.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 226.7ms
# Speed: 3.0ms preprocess, 226.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 239.0ms
# Speed: 4.3ms preprocess, 239.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 219.1ms
# Speed: 3.4ms preprocess, 219.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 226.4ms
# Speed: 3.8ms preprocess, 226.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.657057642862796, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 230.1ms
# Speed: 3.1ms preprocess, 230.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.33402917790419, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.33402917790419, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 233.8ms
# Speed: 3.0ms preprocess, 233.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.91410779201244, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.91410779201244, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.1ms
# Speed: 3.0ms preprocess, 223.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.28407990778366, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.28407990778366, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.31494975142524, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.31494975142524, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.2ms
# Speed: 2.8ms preprocess, 222.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.30599575001124, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.30599575001124, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 227.6ms
# Speed: 4.1ms preprocess, 227.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 64.3826568821032, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 64.3826568821032, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 228.3ms
# Speed: 3.7ms preprocess, 228.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 64.2283287395583, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 64.2283287395583, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 222.8ms
# Speed: 3.3ms preprocess, 222.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.52381189639672, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.52381189639672, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 226.3ms
# Speed: 2.8ms preprocess, 226.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.930386819353515, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.930386819353515, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 217.9ms
# Speed: 3.6ms preprocess, 217.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.623762194130876, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.623762194130876, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 223.4ms
# Speed: 3.4ms preprocess, 223.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.30028095597059, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.30028095597059, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 242.8ms
# Speed: 4.1ms preprocess, 242.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.00636912105603, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.00636912105603, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 243.8ms
# Speed: 3.7ms preprocess, 243.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.8503102597327, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.8503102597327, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 250.1ms
# Speed: 3.9ms preprocess, 250.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.208242745296694, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.208242745296694, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 253.1ms
# Speed: 4.3ms preprocess, 253.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.47389478740351, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.47389478740351, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 257.1ms
# Speed: 3.6ms preprocess, 257.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.61760498577832, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.61760498577832, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 246.1ms
# Speed: 5.0ms preprocess, 246.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.06134469790746, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.06134469790746, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 246.9ms
# Speed: 4.3ms preprocess, 246.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.27788378253808, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.27788378253808, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 246.1ms
# Speed: 4.0ms preprocess, 246.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.40677441043983, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.40677441043983, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 253.2ms
# Speed: 4.3ms preprocess, 253.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.47359280913764, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.47359280913764, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 247.1ms
# Speed: 3.3ms preprocess, 247.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.983381963499696, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.983381963499696, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 244.5ms
# Speed: 3.8ms preprocess, 244.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.843588041757535, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.843588041757535, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 243.1ms
# Speed: 3.8ms preprocess, 243.1ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.10393716253942, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.10393716253942, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 240.0ms
# Speed: 4.7ms preprocess, 240.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.56824649188576, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.56824649188576, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 240.6ms
# Speed: 3.1ms preprocess, 240.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.996967539535405, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.996967539535405, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 247.2ms
# Speed: 4.2ms preprocess, 247.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 63.04518383391357, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 63.04518383391357, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 246.2ms
# Speed: 3.5ms preprocess, 246.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.63157512927678, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.63157512927678, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 243.4ms
# Speed: 3.4ms preprocess, 243.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.35249256533976, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.35249256533976, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 238.0ms
# Speed: 2.9ms preprocess, 238.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 62.12644029192399, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 62.12644029192399, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 247.0ms
# Speed: 3.4ms preprocess, 247.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.793869461082934, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.793869461082934, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 241.1ms
# Speed: 4.9ms preprocess, 241.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.20496912727338, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.20496912727338, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 231.1ms
# Speed: 4.4ms preprocess, 231.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.23478849118508, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.23478849118508, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 250.1ms
# Speed: 3.7ms preprocess, 250.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.120281037030686, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.120281037030686, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 241.4ms
# Speed: 3.8ms preprocess, 241.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.00903214670537, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.00903214670537, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 233.5ms
# Speed: 4.4ms preprocess, 233.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 61.06217599000128, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 61.06217599000128, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 244.4ms
# Speed: 3.4ms preprocess, 244.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.84971859636608, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.84971859636608, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 237.6ms
# Speed: 3.8ms preprocess, 237.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.83457474417745, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.83457474417745, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 243.8ms
# Speed: 4.4ms preprocess, 243.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.43398034981798, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.43398034981798, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 241.3ms
# Speed: 3.9ms preprocess, 241.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.19707689856132, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.19707689856132, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 259.8ms
# Speed: 4.2ms preprocess, 259.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.405349991255676, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.405349991255676, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 246.4ms
# Speed: 3.1ms preprocess, 246.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.102537089920006, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.102537089920006, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 231.2ms
# Speed: 4.2ms preprocess, 231.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.77193797183412, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.77193797183412, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 243.8ms
# Speed: 3.5ms preprocess, 243.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.68042964950325, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.68042964950325, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 264.8ms
# Speed: 3.2ms preprocess, 264.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.318790666018366, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.318790666018366, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 278.5ms
# Speed: 3.8ms preprocess, 278.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.22835905216888, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.22835905216888, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 269.4ms
# Speed: 4.9ms preprocess, 269.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.895738924259845, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.895738924259845, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 244.1ms
# Speed: 4.4ms preprocess, 244.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.82694543639322, 'max_speed_pps': 143.41043346202036}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.82694543639322, 'max_speed_pps': 143.41043346202036}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 269.8ms
# ...
# Speed: 3.9ms preprocess, 242.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.16892407803362, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.16892407803362, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 232.0ms
# Speed: 3.9ms preprocess, 232.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.457959936143425, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.457959936143425, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 227.3ms
# Speed: 3.9ms preprocess, 227.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.28199303074995, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.28199303074995, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 231.3ms
# Speed: 3.7ms preprocess, 231.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.12827906661328, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.12827906661328, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 230.4ms
# Speed: 4.1ms preprocess, 230.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.9316460331963, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.9316460331963, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 240.3ms
# Speed: 3.9ms preprocess, 240.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.83150800841127, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.83150800841127, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 236.8ms
# Speed: 3.7ms preprocess, 236.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 58.961746725463705, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 58.961746725463705, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 336.5ms
# Speed: 3.2ms preprocess, 336.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.04225407155263, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.04225407155263, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 286.3ms
# Speed: 4.0ms preprocess, 286.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.097396667817975, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.097396667817975, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 294.3ms
# Speed: 4.0ms preprocess, 294.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.09587520562904, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.09587520562904, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 247.2ms
# Speed: 3.3ms preprocess, 247.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.21100846643619, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.21100846643619, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 1 sports ball, 242.2ms
# Speed: 3.2ms preprocess, 242.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.5604410673501, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.5604410673501, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 301.7ms
# Speed: 3.8ms preprocess, 301.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.69648400430242, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.69648400430242, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 400.1ms
# Speed: 4.6ms preprocess, 400.1ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.729254425754206, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.729254425754206, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 488.2ms
# Speed: 5.2ms preprocess, 488.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.65983679277743, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.65983679277743, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 542.7ms
# Speed: 13.9ms preprocess, 542.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 59.89963350703055, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 59.89963350703055, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 466.5ms
# Speed: 4.8ms preprocess, 466.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.05163057471944, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.05163057471944, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 572.7ms
# Speed: 3.6ms preprocess, 572.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.122754889527556, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.122754889527556, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 378.6ms
# Speed: 7.9ms preprocess, 378.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 353.5ms
# Speed: 10.3ms preprocess, 353.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 276.7ms
# Speed: 3.6ms preprocess, 276.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 290.2ms
# Speed: 11.6ms preprocess, 290.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 person, 221.2ms
# Speed: 3.8ms preprocess, 221.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 1 kite, 230.4ms
# Speed: 3.9ms preprocess, 230.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 247.5ms
# Speed: 3.6ms preprocess, 247.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 254.7ms
# Speed: 4.0ms preprocess, 254.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 250.5ms
# Speed: 3.3ms preprocess, 250.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 231.6ms
# Speed: 4.0ms preprocess, 231.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 261.5ms
# Speed: 3.6ms preprocess, 261.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 229.4ms
# Speed: 3.7ms preprocess, 229.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 225.1ms
# Speed: 4.2ms preprocess, 225.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 243.2ms
# Speed: 4.9ms preprocess, 243.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 353.6ms
# Speed: 4.0ms preprocess, 353.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 236.4ms
# Speed: 3.7ms preprocess, 236.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 249.1ms
# Speed: 8.8ms preprocess, 249.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 258.4ms
# Speed: 4.3ms preprocess, 258.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 224.4ms
# Speed: 3.7ms preprocess, 224.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 244.8ms
# Speed: 3.5ms preprocess, 244.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 232.6ms
# Speed: 3.6ms preprocess, 232.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 230.6ms
# Speed: 4.4ms preprocess, 230.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0
#
# 0: 640x384 (no detections), 394.3ms
# Speed: 4.0ms preprocess, 394.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# Player 1 -> Speed: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}, Control: 0.00, Juggling: 0
# Speed Metrics: {'average_speed_pps': 60.20422412155226, 'max_speed_pps': 145.2608790876325}
# Ball Control: 0.0%
# Juggling Touches: 0

# %% [markdown]
# # MediaPipe Pose
# mp_drawing = mp.solutions.drawing_utils
# mp_pose    = mp.solutions.pose
# pose       = mp_pose.Pose(
#     static_image_mode=False,
#     model_complexity=1,
#     enable_segmentation=False,
#     min_detection_confidence=0.5,
#     min_tracking_confidence=0.5
# )
#
# # Generate random colors for each class
# np.random.seed(42)
# colors = np.random.randint(0, 255, size=(len(model.names), 3))
#
# # Parameters
# CONF    = 0.8            # confidence threshold
# ALLOWED = [0, 32]        # 0=person, 32=sports ball
#
# # Manual ball tracking
# ball_id         = 1
# last_ball_bbox  = None   # will hold [x, y, w, h] of the ball
#
# # FPS calculation
# frame_count = 0
# start_time  = time.time()
#
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     # 1. Run detection
#     results = model(frame)
#     r       = results[0]
#     xyxy    = r.boxes.xyxy.cpu().numpy()
#     confs   = r.boxes.conf.cpu().numpy()
#     cls_ids = r.boxes.cls.cpu().numpy().astype(int)
#
#     # 2. Build filtered detection list
#     detect = []
#     for (x1, y1, x2, y2), conf, cid in zip(xyxy, confs, cls_ids):
#         if conf < CONF or cid not in ALLOWED:
#             continue
#         detect.append([[int(x1), int(y1), int(x2 - x1), int(y2 - y1)],
#                        float(conf), int(cid)])
#
#     # 3. Track persons with DeepSort
#     person_detections = [d for d in detect if d[2] == 0]
#     tracks            = tracker.update_tracks(person_detections, frame=frame)
#
#     # 4. Manual track for the single sports ball
#     ball_candidates = [d for d in detect if d[2] == 32]
#     if ball_candidates:
#         best_ball       = max(ball_candidates, key=lambda x: x[1])
#         last_ball_bbox  = best_ball[0]
#
#         # ————————— Pose Estimation داخل كل ROI لشخص مؤكد —
#     for track in tracks:
#         if not track.is_confirmed():
#             continue
#         # إحداثيات الـ bounding box
#         x1, y1, x2, y2 = map(int, track.to_ltrb())
#         # قص المنطقة
#         person_roi = frame[y1:y2, x1:x2]
#         if person_roi.size == 0:
#             continue
#         # مرّر ROI للـ Pose model
#         roi_rgb = cv2.cvtColor(person_roi, cv2.COLOR_BGR2RGB)
#         pose_res = pose.process(roi_rgb)
#         # إذا وجد landmarks، ارسمها داخل الـ ROI
#         if pose_res.pose_landmarks:
#             mp_drawing.draw_landmarks(
#                 person_roi,
#                 pose_res.pose_landmarks,
#                 mp_pose.POSE_CONNECTIONS,
#                 mp_drawing.DrawingSpec(thickness=2, circle_radius=2),
#                 mp_drawing.DrawingSpec(thickness=2)
#             )
#             # اعد الـ ROI المرسوم إلى الفريم الأصلي
#             frame[y1:y2, x1:x2] = person_roi
#
#
#     # 5. Draw person tracking results
#     for track in tracks:
#         if not track.is_confirmed():
#             continue
#
#         tid       = track.track_id
#         x1, y1, x2, y2 = map(int, track.to_ltrb())
#         cid       = track.get_det_class()  # should be 0
#         color     = colors[cid]
#         B, G, R   = map(int, color)
#         label     = f"{tid} - {model.names[cid]}"
#
#         # draw corner-style box
#         frame = draw_corner_rect(
#             frame,
#             (x1, y1, x2 - x1, y2 - y1),
#             line_length=15,
#             line_thickness=3,
#             rect_thickness=1,
#             rect_color=(B, G, R),
#             line_color=(R, G, B),
#         )
#         # draw solid rectangle and label background
#         cv2.rectangle(frame, (x1, y1), (x2, y2), (B, G, R), 2)
#         cv2.rectangle(
#             frame,
#             (x1 - 1, y1 - 20),
#             (x1 + len(label) * 10, y1),
#             (B, G, R),
#             -1
#         )
#         cv2.putText(
#             frame,
#             label,
#             (x1 + 5, y1 - 7),
#             cv2.FONT_HERSHEY_SIMPLEX,
#             0.5,
#             (255, 255, 255),
#             2
#         )
#
#     # 6. Draw the sports ball with fixed ID
#     if last_ball_bbox is not None:
#         x, y, w, h = last_ball_bbox
#         color       = colors[32]
#         B, G, R     = map(int, color)
#         label       = f"{ball_id} - sports ball"
#
#         frame = draw_corner_rect(
#             frame,
#             (x, y, w, h),
#             line_length=15,
#             line_thickness=3,
#             rect_thickness=1,
#             rect_color=(B, G, R),
#             line_color=(R, G, B),
#         )
#         cv2.rectangle(frame, (x, y), (x + w, y + h), (B, G, R), 2)
#         cv2.rectangle(frame, (x - 1, y - 20), (x + len(label) * 10, y), (B, G, R), -1)
#         cv2.putText(frame, label, (x + 5, y - 7),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
#
#     # 7. Write frame and update FPS
#     writer.write(frame)
#     frame_count += 1
#     if frame_count % 10 == 0:
#         fps_calc = frame_count / (time.time() - start_time)
#         print(f"FPS: {fps_calc:.2f}")
#
#     # Exit on 'q'
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# # Release resources after loop
# cap.release()
# writer.release()
# cv2.destroyAllWindows()
# pose.close()
